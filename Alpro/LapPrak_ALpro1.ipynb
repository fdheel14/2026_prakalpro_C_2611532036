# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Program Penghitung Luas Persegi”**
#
# **Disusun Oleh :**
#
# **Fadhel Putra Nandes**
#
# **2611531018**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Rifki Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Pemrograman Python dengan judul "Program Penghitung Luas Persegi" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python.
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, 2026
#
# Fadhel Putra Nandes

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi memungkinkan berbagai perhitungan dilakukan dengan bantuan program komputer. Salah satu penerapannya adalah program penghitung luas persegi panjang yang menggunakan rumus panjang × lebar. Pembuatan program ini bertujuan untuk memahami dasar-dasar pemrograman, seperti penggunaan variabel, input, proses, dan output. Melalui praktikum ini, praktikan dapat belajar membuat program sederhana yang mampu menerima nilai panjang dan lebar, menghitung luas secara otomatis, serta menampilkan hasil perhitungan dengan tepat.
#
# ## 1.2 Tujuan
# 1. Memahami penggunaan variabel, input, proses, dan output.
# 2. Menerapkan penggunaan variabel, input, proses, dan output.
# 3. Melakukan operasi penggunaan variabel, input, proses, dan output untuk menghitung luas persegi.
#
# ## 1.3 Manfaat
# 1. Memahami penerapan logika dasar Python, khususnya penggunaan variabel, input, proses, dan output.
# 2. Mempercepat proses perhitungan luas persegi panjang.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Tuliskan penjelasan konsep/teori yang mendasari praktikum ini (definisi, elemen-elemen penting, dsb). Bisa memakai poin bernomor untuk merinci sub-konsep, contoh:
#
# 1. Bahasa Pemrograman Python
# Python merupakan bahasa pemrograman tingkat tinggi yang bersifat interpreted dan berfokus pada keterbacaan kode. Bahasa ini cocok untuk pemula karena struktur sintaksnya intuitif dan tidak memerlukan deklarasi variabel yang rumit.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "C_2611532036"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program Menghitung Luas Persegi

sisi = float(input("Masukkan panjang sisi persegi: "))

luas = sisi * sisi

print("Luas persegi =", luas)

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk menginput panjang sisi persegi
# 2. Bagian kedua berfungsi untuk mengalikan sisi
# 3. Bagian ketiga berfungsi untuk menampilkan hasil dari perkalian sisi

# %% [markdown]
# ### 2.2.2 Program Driver "NamaDriver_2611532036"

# %%
# Tulis/tempel kode program driver di sini

# %% [markdown]
# Penjelasan program driver di atas: ...
#
# Jika hasil run program didapat dari IDE/terminal lain (bukan dari cell notebook ini), masukkan tangkapan layarnya seperti berikut (atur ukuran & posisi tengah):
#
# <div align="center">
# <img src="images/output1.png" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "NamaKelas_NIM"

# %%
# Kode jawaban tugas bagian a

# %% [markdown]
# b. Kode Program Driver "NamaDriver_NIM"

# %%
# Kode jawaban tugas bagian b (driver)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas ini ...

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python adalah bahasa pemrograman yang mudah dipelajari untuk pemula
#
# Dalam konteks pemrograman python, konsep ini memanfaatkan penggunaan variabel, input, proses, dan output, sehingga dapat digunakan untuk mencari luas dari persegi

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Kadir, A. (2018). Dasar Pemrograman Python 3. Yogyakarta: Andi.
# [2] Kurniawan, E. (2021). Belajar Pemrograman Python untuk Pemula. Bandung: Informatika.
# [3] Sianipar, R. H. (2018). Pemrograman Python: Teori dan Implementasi. Jakarta: Elex Media Komputindo.
# [4] W3Schools. (2024). Python Tutorial. Diakses dari situs W3Schools.
